# %% [markdown]
# <a href="https://colab.research.google.com/github/ydkrisdiantoro/graphlabelpy/blob/main/graf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Coba Ndah, ini keluar nggak

# %%
# ini baris kode Indah
#genap
import math

#inisialisasi
m = int(input("Masukkan nilai m genap, m = 2 (mod 4):"))
if(m % 2 == 0):
    n = math.floor(m/2)
    if(n % 2 != 0):
        baris = n
        kolom = n
        A = [[]]
        for i in range(baris - 1):
            A.append([])
        for i in range(baris):
            for j in range(kolom):
                A[i].append(0)
            i += 1
        i = int(n/2)
        j = int((n/2)-1)
        indeks = 1
        print("------")
        while (indeks<=(n*(n+1))/2):
            if (A[j][i] == 0):
                A[j][i] = indeks
            i += 1
            j -= 1
            if (j < 0):
                j = n - 1
            if (i > n - 1):
                i = 0
            if (A[j][i] != 0):
                j -= 1
                i -= 1
            if (j == -1 and i == 0):
                j = n - 1
            indeks += 1
            
        for j in range(n):
            print()
            for i in range(n):
                if (A[j][i] >= 100):
                    print(A[j][i], end="   ")
                elif (A[j][i] >= 10):
                    print(A[j][i], end="   ")
                else:
                    print(A[j][i], end="    ")

# ---------------------------------------------------------
        if(m % 2 == 0):
            n = math.floor(m/2)
            if(n % 2 != 0):
                baris = n
                kolom = n
                A = [[]]
                for i in range(baris - 1):
                    A.append([])
                for i in range(baris):
                    for j in range(kolom):
                        A[i].append(0)
                    i += 1
                i = int(n/2)
                j = int((n/2)-1)
                indeks = 1
                print("------")
                while (indeks<=(n*(n*n+1))/2):
                    if (A[j][i] == 0):
                        A[j][i] = indeks
                    i += 1
                    j -= 1
                    if (j < 0):
                        j = n - 1
                    if (i > n - 1):
                        i = 0
                    if (A[j][i] != 0):
                        j -= 1
                        i -= 1
                    if (j == -1 and i == 0):
                        j = n - 1
                    indeks += 1

                for j in range(n):
                    print()
                    for i in range(n):
                        if (A[j][i] >= 100):
                            print(A[j][i], end="   ")
                        elif (A[j][i] >= 10):
                            print(A[j][i], end="   ")
                        else:
                            print(A[j][i], end="    ")
                    
       
    else:
        print("n bukan ganjil")
else:
  print("m bukan genap")
# Out:
# Masukkan nilai m genap, m = 2 (mod 4):6
# ------
#
# 0    1    6
# 3    5    0
# 4    0    2    ------
#
# 8    1    6
# 3    5    7
# 4    9    2

# %%
#ganjil
n = int(input("Masukkan ukuran matriks M dengan n bilangan ganjil n>=3:"))
baris = n
kolom = n
A = [[]]
for i in range(baris-1):
    A.append([])
for i in range(baris):
    for j in range(kolom):
        A[i].append(0)
    i+= 1
i = int(n/2)
j = int((n/2)-1)
indeks = 1
while (indeks <= (n*(n+1))/2):
    if (A[j][i] == 0):
        A[j][i] = indeks
    i+= 1
    j-= 1
    if (j<0):
        j = n-1
    if (i>n-1):
        i = 0
    if (A[j][i] != 0):
        j-= 1
        i-= 1
        if (j <= n & i <= 0):
            j = n-1
    indeks+= 1

for j in range(n):
    print()
    for i in range(n):
        if (A[j][i]>=100):
            print(A[j][i], end= "   ")
        elif (A[j][i]>=10):
            print(A[j][i], end= "   ")
        else:
            print(A[j][i], end="    ")
# Out:
# Masukkan ukuran matriks M dengan n bilangan ganjil n>=3:5
#
# 0    6    0    2    15
# 10   0    1    14   0
# 0    5    13   0    9
# 4    12   0    8    0
# 11   0    7    0    3

# %%
#genap
import math

m = int(input("Masukkan nilai m genap, m = 2 (mod 4):"))
if(m % 2 == 0):
    n = math.floor(m/2)
    if(n % 2 != 0):
        baris = n
        kolom = n
        A = [[]]
        for i in range(baris - 1):
            A.append([])
        for i in range(baris):
            for j in range(kolom):
                A[i].append(0)
            i += 1
        i = int(n/2)
        j = int((n/2)-1)
        indeks = 1
        while (indeks<=(n*(n+1))/2):
            if (A[j][i] == 0):
                A[j][i] = indeks
            i += 1
            j -= 1
            if (j < 0):
                j = n - 1
            if (i > n - 1):
                i = 0
            if (A[j][i] != 0):
                j -= 1
                i -= 1
            if (j == -1 and i == 0):
                j = n - 1
            indeks += 1
        for j in range(n):
            print()
            for i in range(n):
                if (A[j][i] >= 100):
                    print(A[j][i], end="   ")
                elif (A[j][i] >= 10):
                    print(A[j][i], end="   ")
                else:
                    print(A[j][i], end="    ")
    else:
        print("n bukan ganjil")
else:
  print("m bukan genap")
# Out:
# Masukkan nilai m genap, m = 2 (mod 4):6
#
# 0    1    6
# 3    5    0
# 4    0    2

# %%
#ini baris kode Yayan
#Labelling Total Titik Ajaib pada Graf Lengkap Km dengan m genap

import math

m = int(input("Masukkan nilai m genap, m = 2 (mod 4):")) #dapatkan input m

#cek nilai m genap atau ganjil
if(m%2 == 0):
  #genap

  n = math.floor(m/2);
  print("Nilai inputan m=",m,"\nNilai n=",n)
  
  if(n%2 == 0):
    #genap, kita pakai yang ganjil
    print("Nilai n genap, proses berhenti.")
  else:
    #ganjil, kita pakai ini
    print("Nilai n ganjil, proses berlanjut.")
    baris = kolom = n

    #buat matriks n*n, nolkan semua elemen
    matriks = []
    for i in range(0, baris):
      #print(i)
      matriks.append([])
      for j in range(kolom):
        #print(i,j)
        matriks[i].append(0)
    
    print("Matriks n*n yang terbentuk:")
    for m in matriks:
      print(m)

    i = int(n/2)
    j = int((n/2)-1)
    i = j = 1
    print("ini nilai i dan j ",i, j)
    indeks = 1
    syarat = (n*(n+1))/2
    while (indeks <= syarat):
        if (matriks[j][i] == 0):
            #jika masih 0, ubah nilainya jadi = indeks
            matriks[j][i] = indeks
            i = i + 1
            j = j - 1
            indeks = indeks + 1
        if (i == 0 and j == -1):
            j = n - 1
        if (i > n - 1):
            i = 0
        if (j < 0):
            j = n - 1
        if (matriks[j][i] != 0):
            #jika sudah diisi nilai (!=0), ubah kondisi
            i = i - 1
            j = j - 1
            if (i < 0):
              i = n - i
            if (j < 0):
              j = n - j

    print("Matriks n*n setelah labelling:")
    for m in matriks:
      print(m)

else:
  #ganjil
  print ("Jangan masukkan angka ganjil!")
# Out:
# Masukkan nilai m genap, m = 2 (mod 4):6
# Nilai inputan m= 6
# Nilai n= 3
# Nilai n ganjil, proses berlanjut.
# Matriks n*n yang terbentuk:
# [0, 0, 0]
# [0, 0, 0]
# [0, 0, 0]
# ini nilai i dan j  1 1
# Matriks n*n setelah labelling:
# [4, 0, 2]
# [0, 1, 6]
# [3, 5, 0]
